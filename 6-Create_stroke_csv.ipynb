# %%
import os 
import numpy as np
import matplotlib.pyplot as plt

# %%
stroke_preprocessed_folder='/mnt/compneuro/deepmreye_finetuning/stroke_nifti/'
os.chdir(stroke_preprocessed_folder)

# %%
both_results=np.load('results_both_eyes_stroke.npy', allow_pickle=True)
both_results=both_results.tolist()

# %%
import h5py
import numpy as np
from concurrent.futures import ProcessPoolExecutor
import tqdm  # optional, for progress bar

# ---- 1. File path ----
file_path = '/mnt/compneuro/MULTIBOOT/net/ascratch/people/plgkoba/stroke_BIDS_first_sessions/derivatives/stroke_structure_iter_387.mat'

# ---- 2. Open HDF5 file lazily ----
stroke_structure = h5py.File(file_path, 'r')
stroke_structure=stroke_structure['stroke_structure']
#print("Top-level keys:", list(f.keys()))

# %%
age = stroke_structure['age'][()]

# %%
ages = read_cell(stroke_structure, "age")

# %%
pip install hdf5storage
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import hdf5storage

# Load .mat file
data = hdf5storage.loadmat(file_path)

# Access the variable
stroke_structure = data['stroke_structure']

# Access age (automatically converted)
ages = stroke_structure['age']
print(ages)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 4
#       1 import hdf5storage
#       3 # Load .mat file
# ----> 4 data = hdf5storage.loadmat(file_path)
#       6 # Access the variable
#       7 stroke_structure = data['stroke_structure']
#
# File ~/venvs/deepmreye-gpu/lib/python3.10/site-packages/hdf5storage/__init__.py:2678, in loadmat(file_name, mdict, appendmat, variable_names, marshaller_collection, options, **keywords)
#    2676 data: dict[Any, Any]
#    2677 if variable_names is None:
# -> 2678     data = {pathesc.unescape_path(k): v for k, v in f.items()}
#    2679 else:
#    2680     data = {}
#
# File ~/venvs/deepmreye-gpu/lib/python3.10/site-packages/hdf5storage/__init__.py:2678, in <dictcomp>(.0)
#    2676 data: dict[Any, Any]
#    2677 if variable_names is None:
# -> 2678     data = {pathesc.unescape_path(k): v for k, v in f.items()}
# ...
